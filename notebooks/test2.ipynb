# %%
#import pandas as pd

#df = pd.read_csv("cleaned_housePrice_enhanced.csv")  # یا هر اسم فایل دیتاست تو
#print(df["Address"].unique())

import joblib
model = joblib.load('../models/house_price_model.pkl')
print(model.predict([[50, 2]]))
print(model.predict([[80, 3]]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 8
#       6 import joblib
#       7 model = joblib.load('../models/house_price_model.pkl')
# ----> 8 print(model.predict([[50, 2]]))
#       9 print(model.predict([[80, 3]]))
#
# File d:\vc code\house_price_project\.venv\Lib\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File d:\vc code\house_price_project\.venv\Lib\site-packages\xgboost\sklearn.py:1327, in XGBModel.predict(self, X, output_margin, validate_features, base_margin, iteration_range)
#    1325 if self._can_use_inplace_predict():
#    1326     try:
# -> 1327         predts = self.get_booster().inplace_predict(
#    1328             data=X,
# ...
